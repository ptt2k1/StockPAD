# %% [markdown]
# # Import lib

# %%
import pandas as pd
import os
import glob
from datetime import *
import numpy as np
import csv
import requests
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries

# %% [markdown]
# # Get data

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=1min&month=2009-01&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
data_json = r.json()

print(data_json)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (1min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2009-01-30 19:57:00', '4. Interval': '1min', '5. Output Size': 'Full size', '6. Time Zone': 'US/Eastern'}, 'Time Series (1min)': {'2009-01-30 19:57:00': {'1. open': '53.7400', '2. high': '53.9330', '3. low': '53.4800', '4. close': '53.6770', '5. volume': '209'}, '2009-01-30 17:44:00': {'1. open': '53.7700', '2. high': '53.9620', '3. low': '53.5090', '4. close': '53.7060', '5. volume': '84726'}, '2009-01-30 17:15:00': {'1. open': '54.0890', '2. high': '54.2830', '3. low': '53.8270', '4. close': '54.0260', '5. volume': '2651'}, '2009-01-30 17:14:00': {'1. open': '53.7700', '2. high': '53.9620', '3. low': '53.5090', '4. close': '53.7060', '5. volume': '359'}, '2009-01-30 17:07:00': {'1. open': '53.5640', '2. high': '53.7620', '3. low': '53.3050', '4. close': '53.5070', '5. volume': '334'}, '2009-01-30 16:59:00': {'1. open': '54.0720', '2. high': '54.2660
# ...

# %%
df = pd.DataFrame.from_dict(data_json['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df.columns = columns

# %%
df
# Out:
#                         open     high      low    close volume
# 2009-01-30 19:57:00  53.7400  53.9330  53.4800  53.6770    209
# 2009-01-30 17:44:00  53.7700  53.9620  53.5090  53.7060  84726
# 2009-01-30 17:15:00  54.0890  54.2830  53.8270  54.0260   2651
# 2009-01-30 17:14:00  53.7700  53.9620  53.5090  53.7060    359
# 2009-01-30 17:07:00  53.5640  53.7620  53.3050  53.5070    334
# ...                      ...      ...      ...      ...    ...
# 2009-01-02 08:31:00  49.3750  49.5520  49.1360  49.3170   9110
# 2009-01-02 08:27:00  49.3750  49.5520  49.1360  49.3170   1733
# 2009-01-02 08:17:00  49.3810  49.5580  49.1420  49.3230    104
# 2009-01-02 08:08:00  49.3750  49.5520  49.1360  49.3170   1733
# 2009-01-02 08:00:00  49.5750  49.7520  49.3340  49.5170    104
#
# [8822 rows x 5 columns]

# %% [markdown]
# # Cách 2

# %%
key = 'KUKC3K6NUOUM7MAP'

ts = TimeSeries(key, output_format='pandas')
data, meta = ts.get_intraday('AAPL',  interval='1min',outputsize='full') #TSLA

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2023-07-12 19:59:00   189.99   189.99  189.97    189.99      610.0
# 2023-07-12 19:58:00   189.99   190.00  189.95    189.99      918.0
# 2023-07-12 19:57:00   189.93   189.99  189.93    189.95      248.0
# 2023-07-12 19:56:00   189.95   189.99  189.95    189.95     1055.0
# 2023-07-12 19:55:00   189.99   189.99  189.95    189.99      712.0
# ...                      ...      ...     ...       ...        ...
# 2023-06-14 04:04:00   183.35   183.38  183.34    183.38       56.0
# 2023-06-14 04:03:00   183.34   183.39  183.32    183.35      415.0
# 2023-06-14 04:02:00   183.40   183.40  183.32    183.35     1128.0
# 2023-06-14 04:01:00   183.34   183.47  183.32    183.40      884.0
# 2023-06-14 04:00:00   184.88   184.88  183.17    183.34     1954.0
#
# [17965 rows x 5 columns]

# %%
columns = ['open', 'high', 'low', 'close', 'volume']
data.columns = columns

data['TradeDate'] = data.index.date
data['time'] = data.index.time

# %%
data
# Out:
#                        open    high     low   close  volume   TradeDate  \
# date
# 2023-07-12 19:59:00  189.99  189.99  189.97  189.99   610.0  2023-07-12
# 2023-07-12 19:58:00  189.99  190.00  189.95  189.99   918.0  2023-07-12
# 2023-07-12 19:57:00  189.93  189.99  189.93  189.95   248.0  2023-07-12
# 2023-07-12 19:56:00  189.95  189.99  189.95  189.95  1055.0  2023-07-12
# 2023-07-12 19:55:00  189.99  189.99  189.95  189.99   712.0  2023-07-12
# ...                     ...     ...     ...     ...     ...         ...
# 2023-06-14 04:04:00  183.35  183.38  183.34  183.38    56.0  2023-06-14
# 2023-06-14 04:03:00  183.34  183.39  183.32  183.35   415.0  2023-06-14
# 2023-06-14 04:02:00  183.40  183.40  183.32  183.35  1128.0  2023-06-14
# 2023-06-14 04:01:00  183.34  183.47  183.32  183.40   884.0  2023-06-14
# 2023-06-14 04:00:00  184.88  184.88  183.17  183.34  1954.0  2023-06-14
#
#                          time
# date
# 2023-07-12 19:59:00  19:59:00
# ...

# %% [markdown]
# # 1.APPL

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
aapl_6 = r.json()

#print(aapl_6)
df_aapl6 = pd.DataFrame.from_dict(aapl_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_aapl6.columns = columns

df_aapl6
# Out:
#                          open      high       low     close volume
# 2023-06-30 19:59:00  194.2600  194.3000  194.2000  194.3000   7644
# 2023-06-30 19:58:00  194.1800  194.2600  194.1800  194.2500   4756
# 2023-06-30 19:57:00  194.2300  194.2400  194.2000  194.2300    749
# 2023-06-30 19:56:00  194.2300  194.2500  194.2200  194.2300   1438
# 2023-06-30 19:55:00  194.2200  194.2500  194.2200  194.2300   5248
# ...                       ...       ...       ...       ...    ...
# 2023-06-01 04:04:00  177.4800  177.6700  177.4500  177.6700    517
# 2023-06-01 04:03:00  177.7000  177.7200  177.4300  177.6000    567
# 2023-06-01 04:02:00  177.8000  177.8000  177.4600  177.5500   1631
# 2023-06-01 04:01:00  177.8300  177.9300  177.5600  177.8000   2196
# 2023-06-01 04:00:00  177.8000  177.9700  177.5700  177.8100   1826
#
# [20082 rows x 5 columns]

# %% [markdown]
# # 2.Facebook

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=META&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
fb_6 = r.json()

#print(fb_6)
df_fb6 = pd.DataFrame.from_dict(fb_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_fb6.columns = columns

df_fb6
# Out:
#                          open      high       low     close volume
# 2023-06-30 19:59:00  286.9000  286.9200  286.7000  286.8000    211
# 2023-06-30 19:58:00  286.8300  286.9000  286.7600  286.9000    302
# 2023-06-30 19:57:00  286.8200  286.8800  286.8000  286.8500    164
# 2023-06-30 19:56:00  286.9000  286.9000  286.8200  286.8800     65
# 2023-06-30 19:55:00  286.8000  286.8500  286.8000  286.8500     36
# ...                       ...       ...       ...       ...    ...
# 2023-06-01 04:04:00  263.9600  264.0000  263.9600  264.0000     50
# 2023-06-01 04:03:00  264.2000  264.2600  263.9600  263.9600    133
# 2023-06-01 04:02:00  263.9600  264.0000  263.9600  263.9600    289
# 2023-06-01 04:01:00  264.5800  264.5800  263.9600  263.9600    154
# 2023-06-01 04:00:00  265.0000  265.0000  263.9600  263.9600   1172
#
# [19194 rows x 5 columns]

# %% [markdown]
# # 3.Uber Technologies

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=UBER&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
uber_6 = r.json()

#print(fb_6)
df_uber6 = pd.DataFrame.from_dict(uber_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_uber6.columns = columns

df_uber6
# Out:
#                         open     high      low    close volume
# 2023-06-30 19:59:00  43.0600  43.0600  43.0600  43.0600    505
# 2023-06-30 19:54:00  43.0500  43.0500  43.0500  43.0500      9
# 2023-06-30 19:52:00  43.0700  43.0700  43.0700  43.0700    625
# 2023-06-30 19:51:00  43.0500  43.0800  43.0500  43.0800      5
# 2023-06-30 19:49:00  43.0500  43.0500  43.0500  43.0500     25
# ...                      ...      ...      ...      ...    ...
# 2023-06-01 04:56:00  38.1500  38.1500  38.1500  38.1500     10
# 2023-06-01 04:54:00  38.1500  38.1900  38.1500  38.1900    130
# 2023-06-01 04:31:00  37.9400  37.9400  37.9400  37.9400      1
# 2023-06-01 04:06:00  37.8000  37.8000  37.8000  37.8000    176
# 2023-06-01 04:01:00  37.9400  37.9400  37.9400  37.9400     30
#
# [15225 rows x 5 columns]

# %% [markdown]
# # 4.Adobe

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=ADBE&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
adbe_6 = r.json()

#print(fb_6)
df_adbe6 = pd.DataFrame.from_dict(adbe_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_adbe6.columns = columns

df_adbe6
# Out:
#                          open      high       low     close volume
# 2023-06-30 19:53:00  488.4100  488.4100  488.4100  488.4100    300
# 2023-06-30 19:52:00  488.4000  488.4000  488.4000  488.4000     15
# 2023-06-30 19:51:00  488.6000  488.8100  488.6000  488.8100    101
# 2023-06-30 19:45:00  488.3000  488.3000  488.3000  488.3000     22
# 2023-06-30 19:33:00  488.3000  488.3000  488.3000  488.3000      1
# ...                       ...       ...       ...       ...    ...
# 2023-06-01 04:30:00  414.3000  414.3000  414.3000  414.3000      3
# 2023-06-01 04:28:00  415.8600  415.8600  415.8600  415.8600      5
# 2023-06-01 04:04:00  415.3700  415.3700  415.3700  415.3700      5
# 2023-06-01 04:02:00  413.9900  413.9900  413.6500  413.6500     90
# 2023-06-01 04:00:00  413.2800  413.2800  413.2800  413.2800      1
#
# [15508 rows x 5 columns]

# %% [markdown]
# # 5.Microsoft

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=MSFT&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
mcs_6 = r.json()

#print(fb_6)
df_mcs6 = pd.DataFrame.from_dict(mcs_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_mcs6.columns = columns

df_mcs6
# Out:
#                          open      high       low     close volume
# 2023-06-30 19:59:00  340.9000  340.9000  340.5500  340.6000    263
# 2023-06-30 19:58:00  340.8200  340.9900  340.7300  340.9700    290
# 2023-06-30 19:57:00  340.7000  340.9900  340.5500  340.8100    778
# 2023-06-30 19:56:00  340.7000  340.7000  340.6900  340.7000     29
# 2023-06-30 19:55:00  340.7200  340.7500  340.5300  340.5300    854
# ...                       ...       ...       ...       ...    ...
# 2023-06-01 04:04:00  327.7200  328.0000  327.6200  328.0000    333
# 2023-06-01 04:03:00  328.0100  328.1000  327.6900  327.9500    553
# 2023-06-01 04:02:00  328.0000  328.3400  327.5000  328.1000   1020
# 2023-06-01 04:01:00  328.3400  328.7000  328.0000  328.0000    682
# 2023-06-01 04:00:00  328.8600  329.5000  328.0000  328.0500   1104
#
# [19585 rows x 5 columns]

# %% [markdown]
# # 6.Paypal

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=PYPL&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
pp_6 = r.json()

#print(fb_6)
df_pp6 = pd.DataFrame.from_dict(pp_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_pp6.columns = columns

df_pp6
# Out:
#                         open     high      low    close volume
# 2023-06-30 19:59:00  66.7300  66.7300  66.7300  66.7300     51
# 2023-06-30 19:58:00  66.6700  66.7300  66.6700  66.7300   2026
# 2023-06-30 19:57:00  66.7300  66.7300  66.7300  66.7300     88
# 2023-06-30 19:56:00  66.7100  66.7300  66.6700  66.7300    146
# 2023-06-30 19:55:00  66.7300  66.7300  66.7000  66.7000    270
# ...                      ...      ...      ...      ...    ...
# 2023-06-01 04:04:00  62.0400  62.1700  62.0400  62.1700    224
# 2023-06-01 04:03:00  62.0400  62.1000  62.0400  62.1000    127
# 2023-06-01 04:02:00  62.1600  62.2000  62.0700  62.1000    277
# 2023-06-01 04:01:00  62.2500  62.2500  62.1000  62.1000    517
# 2023-06-01 04:00:00  62.9500  62.9500  62.0800  62.2000    114
#
# [17538 rows x 5 columns]

# %% [markdown]
# # 7. Amazon

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AMZN&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
amz_6 = r.json()

#print(fb_6)
df_amz6 = pd.DataFrame.from_dict(amz_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_amz6.columns = columns

df_amz6
# Out:
#                          open      high       low     close volume
# 2023-06-30 19:59:00  130.1200  130.1200  130.1000  130.1100    352
# 2023-06-30 19:58:00  130.1300  130.1400  130.1200  130.1200   1308
# 2023-06-30 19:57:00  130.1350  130.1400  130.1200  130.1300    206
# 2023-06-30 19:56:00  130.1300  130.1400  130.1200  130.1400    488
# 2023-06-30 19:55:00  130.1300  130.1400  130.1300  130.1350    205
# ...                       ...       ...       ...       ...    ...
# 2023-06-01 04:04:00  120.5200  120.6800  120.5100  120.6800    232
# 2023-06-01 04:03:00  120.7600  120.8600  120.5100  120.5100    448
# 2023-06-01 04:02:00  120.7500  120.7500  120.0600  120.5100    537
# 2023-06-01 04:01:00  120.8100  120.8100  120.5800  120.5800   1072
# 2023-06-01 04:00:00  120.5800  120.7900  120.5000  120.5800   1149
#
# [19795 rows x 5 columns]

# %% [markdown]
# # 8.Alibaba

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=BABA&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
bb_6 = r.json()

#print(fb_6)
df_bb6 = pd.DataFrame.from_dict(bb_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_bb6.columns = columns

df_bb6
# Out:
#                         open     high      low    close volume
# 2023-06-30 19:59:00  83.3000  83.3900  83.3000  83.3700   2170
# 2023-06-30 19:58:00  83.2810  83.3000  83.2810  83.3000    218
# 2023-06-30 19:57:00  83.3000  83.3000  83.2900  83.3000    432
# 2023-06-30 19:56:00  83.3000  83.3000  83.2900  83.3000     42
# 2023-06-30 19:55:00  83.2900  83.2900  83.2800  83.2900    909
# ...                      ...      ...      ...      ...    ...
# 2023-06-01 04:04:00  79.0300  79.0300  79.0000  79.0000    469
# 2023-06-01 04:03:00  79.0000  79.0300  79.0000  79.0000   1110
# 2023-06-01 04:02:00  79.0500  79.0500  79.0500  79.0500    780
# 2023-06-01 04:01:00  78.9000  79.0500  78.9000  79.0200   3418
# 2023-06-01 04:00:00  79.0300  79.5500  78.9600  78.9800   2477
#
# [18722 rows x 5 columns]

# %% [markdown]
# # 9. The Walt Disney

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=DIS&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
dis_6 = r.json()

#print(fb_6)
df_dis6 = pd.DataFrame.from_dict(dis_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_dis6.columns = columns

df_dis6
# Out:
#                         open     high      low    close volume
# 2023-06-30 19:59:00  89.1000  89.1000  89.0800  89.1000    284
# 2023-06-30 19:58:00  89.1000  89.1000  89.1000  89.1000    225
# 2023-06-30 19:57:00  89.1000  89.1000  89.1000  89.1000     11
# 2023-06-30 19:56:00  89.1000  89.1000  89.0500  89.1000    216
# 2023-06-30 19:55:00  89.0980  89.1000  89.0990  89.1000    335
# ...                      ...      ...      ...      ...    ...
# 2023-06-01 04:06:00  88.2300  88.2300  88.1000  88.1000    102
# 2023-06-01 04:03:00  88.2100  88.2300  88.2000  88.2300     21
# 2023-06-01 04:02:00  88.2100  88.2100  88.2100  88.2100      1
# 2023-06-01 04:01:00  88.2300  88.2300  88.2300  88.2300      4
# 2023-06-01 04:00:00  88.0900  88.3800  88.0900  88.2300      6
#
# [18432 rows x 5 columns]

# %% [markdown]
# # 10.Spotify

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=SPOT&interval=1min&month=2023-06&outputsize=full&apikey=KUKC3K6NUOUM7MAP'
r = requests.get(url)
spot_6 = r.json()

#print(fb_6)
df_spot6 = pd.DataFrame.from_dict(spot_6['Time Series (1min)'], orient='index')

columns = ['open', 'high', 'low', 'close', 'volume']
df_spot6.columns = columns

df_spot6
# Out:
#                          open      high       low     close volume
# 2023-06-30 19:59:00  160.4500  160.4500  160.4500  160.4500      2
# 2023-06-30 19:57:00  160.3100  160.3100  160.3100  160.3100     35
# 2023-06-30 19:47:00  159.0000  159.0000  159.0000  159.0000      1
# 2023-06-30 19:22:00  158.7500  158.7500  158.7500  158.7500      6
# 2023-06-30 19:00:00  160.5500  160.5500  160.5500  160.5500  76773
# ...                       ...       ...       ...       ...    ...
# 2023-06-01 04:14:00  147.9100  147.9200  147.9100  147.9200      4
# 2023-06-01 04:08:00  147.9500  147.9600  147.9500  147.9600    101
# 2023-06-01 04:06:00  148.5000  148.5000  148.5000  148.5000      2
# 2023-06-01 04:05:00  147.6000  147.6000  147.6000  147.6000      1
# 2023-06-01 04:03:00  147.7100  147.7100  147.7000  147.7000      2
#
# [9759 rows x 5 columns]

# %% [markdown]
# # Save csv

# %%
df_aapl6.to_csv('1AAPL.csv')
df_fb6.to_csv('2META.csv')
df_uber6.to_csv('3UBER.csv')
df_adbe6.to_csv('4ADBE.csv')
df_mcs6.to_csv('5MSFT.csv')
df_pp6.to_csv('6PYPL.csv')
df_amz6.to_csv('7AMZN.csv')
df_bb6.to_csv('8BABA.csv')
df_dis6.to_csv('9DIS.csv')
df_spot6.to_csv('10SPOT.csv')

# %%
# Out:
#          2023-06-30 19:59:00 2023-06-30 19:58:00 2023-06-30 19:57:00  \
# close
# 286.8000            194.3000            194.2500            194.2300
# 286.9000            194.3000            194.2500            194.2300
# 286.8500            194.3000            194.2500            194.2300
# 286.8800            194.3000            194.2500            194.2300
# 286.8500            194.3000            194.2500            194.2300
# ...                      ...                 ...                 ...
# 264.0000            194.3000            194.2500            194.2300
# 263.9600            194.3000            194.2500            194.2300
# 263.9600            194.3000            194.2500            194.2300
# 263.9600            194.3000            194.2500            194.2300
# 263.9600            194.3000            194.2500            194.2300
#
#          2023-06-30 19:56:00 2023-06-30 19:55:00 2023-06-30 19:54:00  \
# close
# ...

# %% [markdown]
# # Process

# %%
path='C:/Users/admin/3D Objects/ĐATNCN/alphavantage/'
objects = os.listdir(path)
files_file = [f for f in objects if os.path.isfile(os.path.join(path, f))]

print(files_file)
# Out:
# ['1-alphavantage_demo.ipynb', '10SPOT.csv', '1AAPL.csv', '2-alphavantage_demo.ipynb', '2META.csv', '3-momentum_algorithmic.ipynb', '3UBER.csv', '4-quant_analysis.ipynb', '4ADBE.csv', '5MSFT.csv', '6-mean_reversion.ipynb', '6PYPL.csv', '7-regression.ipynb', '7AMZN.csv', '8BABA.csv', '9DIS.csv', 'aapl.ipynb', 'aapl_3month.csv', 'Data.ipynb', 'README.md']

# %%
list_data = ['1AAPL.csv', '2META.csv','3UBER.csv','4ADBE.csv','5MSFT.csv','6PYPL.csv','7AMZN.csv','8BABA.csv','9DIS.csv'];

df = pd.DataFrame()

for i in list_data:
    data = pd.read_csv(i)
    listt = pd.DataFrame(list(data['close'][:15000]))
    #df[i][:15000] = close
    df = pd.concat([df, listt[:].T],ignore_index=True)

# %%
len(close)
# Out:
# 15000

# %%
df
# Out:
#     0       1       2       3        4       5       6       7        8      \
# 0  194.30  194.25  194.23  194.23  194.230  194.22  194.20  194.20  194.215
# 1  286.80  286.90  286.85  286.88  286.850  286.80  286.80  286.80  286.880
# 2   43.06   43.05   43.07   43.08   43.050   43.08   43.08   43.08   43.050
# 3  488.41  488.40  488.81  488.30  488.300  488.30  488.21  488.60  488.110
# 4  340.60  340.97  340.81  340.70  340.530  340.75  340.50  340.55  340.600
# 5   66.73   66.73   66.73   66.73   66.700   66.75   66.75   66.77   66.800
# 6  130.11  130.12  130.13  130.14  130.135  130.13  130.14  130.13  130.135
# 7   83.37   83.30   83.30   83.30   83.290   83.29   83.28   83.28   83.280
# 8   89.10   89.10   89.10   89.10   89.100   89.10   89.10   89.10   89.100
#
#     9      ...    14990    14991   14992   14993   14994    14995    14996  \
# 0  194.20  ...  177.760  177.850  178.00  177.89  178.00  177.930  177.840
# ...

# %%
df.to_csv('data_svm.csv')
